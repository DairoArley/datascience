# %%
import pandas as pd
import numpy as np

data = pd.read_csv(filepath_or_buffer="../datasets/titanic/titanic3.csv", sep=",", dtype={"age":np.float32}, header=0 )
datos = pd.read_csv(filepath_or_buffer= "../datasets/customer-churn-model/Customer Churn Model.txt")
datos.head()
# Out:
#   State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 0    KS             128        415  382-4657         no        yes
# 1    OH             107        415  371-7191         no        yes
# 2    NJ             137        415  358-1921         no         no
# 3    OH              84        408  375-9999        yes         no
# 4    OK              75        415  330-6626        yes         no
#
#    VMail Message  Day Mins  Day Calls  Day Charge  ...  Eve Calls  Eve Charge  \
# 0             25     265.1        110       45.07  ...         99       16.78
# 1             26     161.6        123       27.47  ...        103       16.62
# 2              0     243.4        114       41.38  ...        110       10.30
# 3              0     299.4         71       50.90  ...         88        5.26
# 4              0     166.7        113       28.34  ...        122       12.61
#
#    Night Mins  Night Calls  Night Charge  Intl Mins  Intl Calls  Intl Charge  \
# ...

# %%
### Qué hacer con lo valores faltantes?

# %%
pd.isnull(data["body"]).values.ravel().sum()
# Out:
# 1188

# %%
pd.notnull(data["body"]).values.ravel().sum()
# Out:
# 121

# %%
data1 = data.dropna(axis=0, how="all") ## Elimina la fila en este caso, si todos los valores son NA
data1 = data.dropna(axis=0, how="any") ## Elimina la fila en este caso, si al menos uno de lo valores es NA
data1
# Out:
# Empty DataFrame
# Columns: [pclass, survived, name, sex, age, sibsp, parch, ticket, fare, cabin, embarked, boat, body, home.dest]
# Index: []

# %%
data2 = data.fillna(0)
data2 = data.fillna("desconocido")
data2
# Out:
#       pclass  survived                                               name  \
# 0          1         1                      Allen, Miss. Elisabeth Walton
# 1          1         1                     Allison, Master. Hudson Trevor
# 2          1         0                       Allison, Miss. Helen Loraine
# 3          1         0               Allison, Mr. Hudson Joshua Creighton
# 4          1         0    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 5          1         1                                Anderson, Mr. Harry
# 6          1         1                  Andrews, Miss. Kornelia Theodosia
# 7          1         0                             Andrews, Mr. Thomas Jr
# 8          1         1      Appleton, Mrs. Edward Dale (Charlotte Lamson)
# 9          1         0                            Artagaveytia, Mr. Ramon
# 10         1         0                             Astor, Col. John Jacob
# 11         1         1  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# ...

# %%
data3 = data
data3["body"] = data3["body"].fillna(0) ## se cambia por un valor constante
data3["home.dest"] = data3["home.dest"].fillna("Desconocido")
data3
# Out:
#       pclass  survived                                               name  \
# 0          1         1                      Allen, Miss. Elisabeth Walton
# 1          1         1                     Allison, Master. Hudson Trevor
# 2          1         0                       Allison, Miss. Helen Loraine
# 3          1         0               Allison, Mr. Hudson Joshua Creighton
# 4          1         0    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 5          1         1                                Anderson, Mr. Harry
# 6          1         1                  Andrews, Miss. Kornelia Theodosia
# 7          1         0                             Andrews, Mr. Thomas Jr
# 8          1         1      Appleton, Mrs. Edward Dale (Charlotte Lamson)
# 9          1         0                            Artagaveytia, Mr. Ramon
# 10         1         0                             Astor, Col. John Jacob
# 11         1         1  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# ...

# %%
data4 = data
data4 = data4["age"].fillna(data["age"].mean())
data4
# Out:
# 0       29.000000
# 1        0.916700
# 2        2.000000
# 3       30.000000
# 4       25.000000
# 5       48.000000
# 6       63.000000
# 7       39.000000
# 8       53.000000
# 9       71.000000
# 10      47.000000
# 11      18.000000
# 12      24.000000
# 13      26.000000
# 14      80.000000
# 15      29.881136
# 16      24.000000
# 17      50.000000
# 18      32.000000
# 19      36.000000
# 20      37.000000
# 21      47.000000
# 22      26.000000
# 23      42.000000
# 24      29.000000
# 25      25.000000
# 26      25.000000
# 27      19.000000
# 28      35.000000
# 29      28.000000
#           ...
# 1279    14.000000
# 1280    22.000000
# 1281    22.000000
# 1282    29.881136
# 1283    29.881136
# 1284    29.881136
# 1285    32.500000
# 1286    38.000000
# 1287    51.000000
# 1288    18.000000
# 1289    21.000000
# 1290    47.000000
# 1291    29.881136
# 1292    29.881136
# 1293    29.881136
# 1294    28.500000
# 1295    21.000000
# 1296    27.000000
# 1297    29.881136
# ...

# %%
###otro inputación
data5 = data5["age"].fillna(method="ffill") ## forward
